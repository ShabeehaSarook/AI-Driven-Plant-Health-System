# %%
import pandas as pd

df = pd.read_csv("../data/plant_health_data.csv")
df.head()
# Out:
#   Timestamp  Plant_ID  Soil_Moisture  Ambient_Temperature  Soil_Temperature  \
# 0   54:53.4         1      27.521109            22.240245         21.900435
# 1   54:53.4         1      14.835566            21.706763         18.680892
# 2   54:53.4         1      17.086362            21.180946         15.392939
# 3   54:53.4         1      15.336156            22.593302         22.778394
# 4   54:53.4         1      39.822216            28.929001         18.100937
#
#     Humidity  Light_Intensity   Soil_pH  Nitrogen_Level  Phosphorus_Level  \
# 0  55.291904       556.172805  5.581955       10.003650         45.806852
# 1  63.949181       596.136721  7.135705       30.712562         25.394393
# 2  67.837956       591.124627  5.656852       29.337002         27.573892
# 3  58.190811       241.412476  5.584523       16.966621         26.180705
# 4  63.772036       444.493830  5.919707       10.944961         37.898907
#
# ...

# %%
df.shape
# Out:
# (1200, 14)

# %%
df.columns
# Out:
# Index(['Timestamp', 'Plant_ID', 'Soil_Moisture', 'Ambient_Temperature',
#        'Soil_Temperature', 'Humidity', 'Light_Intensity', 'Soil_pH',
#        'Nitrogen_Level', 'Phosphorus_Level', 'Potassium_Level',
#        'Chlorophyll_Content', 'Electrochemical_Signal', 'Plant_Health_Status'],
#       dtype='object')

# %%
df["target"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\HP\AI-Driven-Plant-Health-System\venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'target'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ...

# %%
df.columns
# Out:
# Index(['Timestamp', 'Plant_ID', 'Soil_Moisture', 'Ambient_Temperature',
#        'Soil_Temperature', 'Humidity', 'Light_Intensity', 'Soil_pH',
#        'Nitrogen_Level', 'Phosphorus_Level', 'Potassium_Level',
#        'Chlorophyll_Content', 'Electrochemical_Signal', 'Plant_Health_Status'],
#       dtype='object')

# %%
df.rename(columns={"Plant_Health_Status": "target"}, inplace=True)

# %%
df.to_csv("../data/plant_health_data.csv", index=False)

# %%
df["target"].value_counts()
# Out:
# target
# High Stress        500
# Moderate Stress    401
# Healthy            299
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Timestamp                 0
# Plant_ID                  0
# Soil_Moisture             0
# Ambient_Temperature       0
# Soil_Temperature          0
# Humidity                  0
# Light_Intensity           0
# Soil_pH                   0
# Nitrogen_Level            0
# Phosphorus_Level          0
# Potassium_Level           0
# Chlorophyll_Content       0
# Electrochemical_Signal    0
# target                    0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Timestamp                 0
# Plant_ID                  0
# Soil_Moisture             0
# Ambient_Temperature       0
# Soil_Temperature          0
# Humidity                  0
# Light_Intensity           0
# Soil_pH                   0
# Nitrogen_Level            0
# Phosphorus_Level          0
# Potassium_Level           0
# Chlorophyll_Content       0
# Electrochemical_Signal    0
# Plant_Health_Status       0
# dtype: int64
